# %%
import pandas as pd

# %%
dfClientes = pd.read_excel('base_dados.xlsx', sheet_name= 'Cliente')
dfVendas = pd.read_excel('base_dados.xlsx', sheet_name='Venda')
dfVendedores = pd.read_excel('base_dados.xlsx', sheet_name='vendedor')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\efrai\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File c:\Users\efrai\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
dfClientes[dfClientes.isnull().T.any()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\git\analise_final\analise_final.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/git/analise_final/analise_final.ipynb#ch0000001?line=0'>1</a> dfClientes[dfClientes.isnull().T.any()]
#
# NameError: name 'dfClientes' is not defined

# %%
dfClientes.describe()
# Out:
#                 ID    Vendedor
# count   912.000000  912.000000
# mean    979.740132    6.101974
# std     339.531742    5.818846
# min       0.000000    0.000000
# 25%     785.750000    1.000000
# 50%    1019.500000    4.000000
# 75%    1247.250000   13.000000
# max    1475.000000   19.000000

# %%
dfClientes.loc[dfClientes.Nome.isnull(),'Nome'] = '0'
dfClientes.loc[dfClientes.Cidade.isnull(),'Cidade'] = '0'
dfClientes.loc[dfClientes.UF.isnull(),'UF'] = '0'
dfClientes.loc[dfClientes.Vendedor.isnull(), 'Vendedor'] = '0'

# %%
dfClientes
# Out:
#        ID                            Nome            Cidade  UF Vendedor
# 0       0                               0                 0   0        0
# 1       1                      CONSUMIDOR                 0   0        1
# 2       3      ABENILDO MORAES DA FONSECA                 0   0        1
# 3       5        Adeildo alves cavalcante                 0   0        1
# 4      10                         Aderval                 0   0        1
# ..    ...                             ...               ...  ..      ...
# 907   923  GERRI ADRIANO ALVES DE ALMEIDA         VENTUROSA  PE        1
# 908  1272        JOSE VIANA DA SILVA NETO         VENTUROSA  PE        1
# 909   967             JAIRO JOSE DA SILVA          VICENCIA  PE        1
# 910  1277      FABIA - VALDOMIRO PRODUTOR  VILA DO CRUZEIRO  PE        1
# 911  1090       LEANDRO S DA SILVA EIRELI             XEXEU  PE       12
#
# [912 rows x 5 columns]

# %%
dfVendas.isnull().sum()
# Out:
# id               0
# id_cliente       0
# id_vendedor    455
# Data_Venda       0
# Entrada          1
# Desconto         0
# Parcelas         0
# valor1          47
# Cheques          1
# dtype: int64
